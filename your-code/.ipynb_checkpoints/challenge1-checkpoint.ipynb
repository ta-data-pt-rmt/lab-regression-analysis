# %% [markdown]
# # Lab: Regression Analysis

# %% [markdown]
# ### Before you start:
#
# * Read the README.md file
# * Comment as much as you can and use the resources (README.md file)
#
# Happy learning!

# %% [markdown]
# ## Challenge 1
# I work at a coding bootcamp, and I have developed a theory that the younger my students are, the more often they are late to class. In order to test my hypothesis, I have collected some data in the following table:
#
# | StudentID | Age | Tardies |
# |--------|-----|------------|
# | 1      | 17  | 10         |
# | 2      | 51  | 1          |
# | 3      | 27  | 5          |
# | 4      | 21  | 9         |
# | 5      | 36  |  4         |
# | 6      | 48  |  2         |
# | 7      | 19  |  9         |
# | 8      | 26  | 6          |
# | 9      | 54  |  0         |
# | 10     | 30  |  3         |

# %% [markdown]
# Use this command to create a dataframe with the data provided in the table.
# ~~~~
# student_data = pd.DataFrame({'X': [x_values], 'Y': [y_values]})
# ~~~~

# %%
# Your code here.
import pandas as pd

student_data = pd.DataFrame({
    'X': [17, 51, 27, 21, 36, 48, 19, 26, 54, 30],  # Age
    'Y': [10, 1, 5, 9, 4, 2, 9, 6, 0, 3]  # Tardies
})

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data.

# %%
# Your code here.
import matplotlib.pyplot as plt

# Creating the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(student_data['X'], student_data['Y'])
plt.title("Scatter plot of 'Age' vs 'Tardies'")
plt.xlabel('Age')
plt.ylabel('Tardies')
plt.grid(True)
plt.show()

# %% [markdown]
# Do you see a trend? Can you make any hypotheses about the relationship between age and number of tardies?

# %%
# The plot seems to suggest a negative correlation between the two variables, as younger students tend to be late more often. However, we need to conduct a statistical analysis to confirm this correlation.

# %% [markdown]
# Calculate the covariance and correlation of the variables in your plot. What is the difference between these two measures? Compare their values. What do they tell you in this case? Add your responses as comments after your code.

# %%
# Your response here.
# Calculating covariance
covariance = student_data.cov().loc['X', 'Y']

# Calculating correlation
correlation = student_data.corr().loc['X', 'Y']

covariance, correlation
# Out:
# (-45.56666666666666, -0.9391626886887121)

# %% [markdown]
# In this case, the negative covariance indicates that there is a general trend of decreasing tardiness with increasing age. The negative correlation, which is close to -1, suggests a strong negative linear relationship between age and tardiness. This confirms our initial observation from the scatter plot and supports the hypothesis that younger students are more often late to class.

# %% [markdown]
# Build a regression model for this data. What will be your outcome variable? What type of regression are you using? Add your responses as comments after your code.

# %%
# Your response here.
from sklearn.linear_model import LinearRegression

# Reshaping the data for the model
X = student_data['X'].values.reshape(-1, 1)  # Age
Y = student_data['Y'].values.reshape(-1, 1)  # Tardies

# Creating a Linear Regression model
model = LinearRegression()

# Fitting the model with the data
model.fit(X, Y)

# Getting the model's parameters
slope = model.coef_[0][0]
intercept = model.intercept_[0]

slope, intercept
# Out:
# (-0.2428207709159808, 12.888803363135768)

# %% [markdown]
# Plot your regression model on your scatter plot.

# %%
# Your code here.
# Importing matplotlib again after reset
import matplotlib.pyplot as plt

# Predicting tardies from the ages using the regression model
Y_pred = model.predict(X)

# Creating the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(student_data['X'], student_data['Y'], label='Observed')
plt.plot(student_data['X'], Y_pred, color='red', label='Fitted line')
plt.title("Scatter plot of 'Age' vs 'Tardies' with fitted regression line")
plt.xlabel('Age')
plt.ylabel('Tardies')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Interpret the results of your model. What can conclusions can you draw from your model and how confident in these conclusions are you? Can we say that age is a good predictor of tardiness? Add your responses as comments after your code.

# %%
"the line provides a good fit to the data, suggesting that the model accurately captures the downward trend. This means the model supports the hypothesis that there is a negative relationship between a student's age and their frequency of tardiness."

# %% [markdown]
# ## Challenge 2
# For the second part of this lab, we will use the vehicles.csv data set. You can find a copy of the dataset in the git hub folder. This dataset includes variables related to vehicle characteristics, including the model, make, and energy efficiency standards, as well as each car's CO2 emissions. As discussed in class the goal of this exercise is to predict vehicles' CO2 emissions based on several independent variables.

# %%
# Import any libraries you may need & the data
vehicles = pd.read_csv("C:\\Users\\carmo\\Desktop\\IronHack\\Week 4\\Day 3\\lab-regression-analysis\\your-code\\vehicles.csv")

# %% [markdown]
# Let's use the following variables for our analysis: Year, Cylinders, Fuel Barrels/Year, Combined MPG, and Fuel Cost/Year. We will use 'CO2 Emission Grams/Mile' as our outcome variable.
#
# Calculate the correlations between each of these variables and the outcome. Which variable do you think will be the most important in determining CO2 emissions? Which provides the least amount of helpful information for determining CO2 emissions? Add your responses as comments after your code.

# %%
# Your response here. 

# Selecting the variables for our analysis
selected_variables = ['Year', 'Cylinders', 'Fuel Barrels/Year', 'Combined MPG', 'Fuel Cost/Year', 'CO2 Emission Grams/Mile']

# Creating a new DataFrame with the selected variables
vehicles_selected = vehicles[selected_variables]

# Calculating the correlations between the selected variables and the outcome variable
correlations = vehicles_selected.corr()['CO2 Emission Grams/Mile'].sort_values(ascending=False)

correlations
# Out:
# CO2 Emission Grams/Mile    1.000000
# Fuel Barrels/Year          0.986189
# Fuel Cost/Year             0.930865
# Cylinders                  0.752393
# Year                      -0.222300
# Combined MPG              -0.926229
# Name: CO2 Emission Grams/Mile, dtype: float64

# %% [markdown]
# Build a regression model for this data. What type of regression are you using? Add your responses as comments after your code.

# %%
# Your response here. 
# Defining the predictor variables and the outcome variable
X = vehicles_selected[['Year', 'Cylinders', 'Fuel Barrels/Year', 'Combined MPG', 'Fuel Cost/Year']]
Y = vehicles_selected['CO2 Emission Grams/Mile']

# Creating a Linear Regression model
model = LinearRegression()

# Fitting the model with the data
model.fit(X, Y)

# Getting the model's parameters
coefficients = model.coef_
intercept = model.intercept_

coefficients, intercept
# Out:
# (array([-0.32061673,  1.87879976, 19.05292507, -3.04039938,  0.03230948]),
#  769.8882836465821)

# %% [markdown]
# The linear regression model that we have built has the following parameters:
#
# Coefficients for 'Year', 'Cylinders', 'Fuel Barrels/Year', 'Combined MPG', 'Fuel Cost/Year': Approximately -0.321, 1.879, 19.053, -3.040, and 0.032, respectively
# Intercept (constant term): Approximately 769.888

# %% [markdown]
# Print your regression summary, and interpret the results. What are the most important varibles in your model and why? What can conclusions can you draw from your model and how confident in these conclusions are you? Add your responses as comments after your code.

# %%
# Your response here. 
import statsmodels.api as sm

# Adding a constant to the predictor variables
X = sm.add_constant(X)

# Fitting the OLS model
model = sm.OLS(Y, X)
results = model.fit()

# Printing the summary
print(results.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     CO2 Emission Grams/Mile   R-squared:                       0.981
# Model:                                 OLS   Adj. R-squared:                  0.981
# Method:                      Least Squares   F-statistic:                 3.687e+05
# Date:                     Thu, 03 Aug 2023   Prob (F-statistic):               0.00
# Time:                             23:30:22   Log-Likelihood:            -1.5173e+05
# No. Observations:                    35952   AIC:                         3.035e+05
# Df Residuals:                        35946   BIC:                         3.035e+05
# Df Model:                                5
# Covariance Type:                 nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Based on the coefficients and their statistical significance, 'Fuel Barrels/Year' seems to be the most important variable in our model because it has the highest coefficient and a very low p-value. This means that 'Fuel Barrels/Year' has a large effect on 'CO2 Emission Grams/Mile' and this effect is statistically significant.
#
# 'Year' seems to provide the least amount of helpful information for determining CO2 emissions in our model. Even though it is statistically significant, it has the smallest absolute value of the coefficient, indicating that it has the smallest effect on the outcome variable among all predictors.

# %% [markdown]
# ## Challenge 2: Error Analysis

# %% [markdown]
# I am suspicious about the last few parties I have thrown: it seems that the more people I invite the more people are unable to attend. To know if my hunch is supported by data, I have decided to do an analysis. I have collected my data in the table below, where X is the number of people I invited, and Y is the number of people who attended.
#
# |  X |  Y |
# |----|----|
# | 1  |  1 |
# | 3  |  2 |
# | 4  |  4 |
# | 6  |  4 |
# | 8  |  5 |
# | 9  |  7 |
# | 11 |  8 |
# | 14 |  13 |

# %% [markdown]
# We want to know if the relationship modeled by the two random variables is linear or not, and therefore if it is appropriate to model it with a linear regression.
# First, build a dataframe with the data.

# %%
# Your code here.
party_data = pd.DataFrame({
    'X': [1, 3, 4, 6, 8, 9, 11, 14],  # Number of people invited
    'Y': [1, 2, 4, 4, 5, 7, 8, 13]  # Number of people attended
})

party_data
# Out:
#     X   Y
# 0   1   1
# 1   3   2
# 2   4   4
# 3   6   4
# 4   8   5
# 5   9   7
# 6  11   8
# 7  14  13

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data, and fit a regression line.

# %%
# Your code here.
# Defining the predictor variables and the outcome variable
X = party_data['X'].values.reshape(-1, 1)  # Number of people invited
Y = party_data['Y'].values.reshape(-1, 1)  # Number of people attended

# Creating a Linear Regression model
model = LinearRegression()

# Fitting the model with the data
model.fit(X, Y)

# Predicting attendance from the number of people invited using the regression model
Y_pred = model.predict(X)

# Creating the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(party_data['X'], party_data['Y'], label='Observed')
plt.plot(party_data['X'], Y_pred, color='red', label='Fitted line')
plt.title("Scatter plot of 'Number of people invited' vs 'Number of people attended' with fitted regression line")
plt.xlabel('Number of people invited')
plt.ylabel('Number of people attended')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# What do you see? What does this plot tell you about the likely relationship between the variables? Print the results from your regression.

# %%
# Your response here. 
# Getting the model's parameters
slope = model.coef_[0][0]
intercept = model.intercept_[0]

slope, intercept
# Out:
# (0.8484848484848485, -0.43939393939393945)

# %% [markdown]
# According to our model, for each additional person you invite, you can expect approximately 0.848 more people to attend, assuming that the relationship between the number of people invited and the number of attendees is indeed linear. The intercept of -0.439 is the expected number of attendees if no one is invited, which doesn't make sense in the context of our problem but is a necessary part of the linear model.
#
# The scatter plot and the fitted line suggest a positive relationship between the number of people invited and the number of people who attended. This means that inviting more people tends to result in more attendees. However, the relationship might not be perfectly linear, as the data points do not all fall exactly on the fitted line. This could mean that other factors not considered in this analysis might also influence the number of attendees.

# %% [markdown]
# Do you see any problematic points, or outliers, in your data? Remove these points and recalculate your regression. Print the new dispersion diagram with your new model and the results of your model.

# %%
# Your response here. 
"Looking at the scatter plot, one point stands out as potentially problematic. When 6 people were invited, only 4 attended, which is lower than we would expect based on the overall trend. Similarly, when 14 people were invited, 13 attended, which is higher than expected. These points could be considered outliers."

"Let's remove these points and recalculate the regression."

# Removing the outliers
party_data_filtered = party_data.drop(party_data[(party_data['X'] == 6) | (party_data['X'] == 14)].index)

# Defining the predictor variables and the outcome variable
X_filtered = party_data_filtered['X'].values.reshape(-1, 1)  # Number of people invited
Y_filtered = party_data_filtered['Y'].values.reshape(-1, 1)  # Number of people attended

# Creating a Linear Regression model
model_filtered = LinearRegression()

# Fitting the model with the data
model_filtered.fit(X_filtered, Y_filtered)

# Predicting attendance from the number of people invited using the regression model
Y_pred_filtered = model_filtered.predict(X_filtered)

# Creating the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(party_data_filtered['X'], party_data_filtered['Y'], label='Observed')
plt.plot(party_data_filtered['X'], Y_pred_filtered, color='red', label='Fitted line')
plt.title("Scatter plot of 'Number of people invited' vs 'Number of people attended' with fitted regression line (outliers removed)")
plt.xlabel('Number of people invited')
plt.ylabel('Number of people attended')
plt.legend()
plt.grid(True)
plt.show()

# Getting the model's parameters
slope_filtered = model_filtered.coef_[0][0]
intercept_filtered = model_filtered.intercept_[0]

slope_filtered, intercept_filtered
# Out:
# (0.6842105263157895, 0.39473684210526283)

# %% [markdown]
# According to our new model, for each additional person you invite, you can expect approximately 0.684 more people to attend. The intercept of 0.394 is the expected number of attendees if no one is invited, which still doesn't make practical sense but is a necessary part of the linear model.
#
# The scatter plot with the new fitted line shows a clearer upward trend, which suggests a positive relationship between the number of people invited and the number of people who attended. The line fits the data points more closely now that the outliers have been removed

# %% [markdown]
# What changed? Based on the results of the two models and your graphs, what can you say about the form of the data with the problematic point and without it?

# %% [markdown]
# # Your response here.
# After removing the outliers, the slope of the fitted line decreased from approximately 0.848 to approximately 0.684. This means that the estimated increase in the number of attendees for each additional person invited is smaller in the new model. The intercept of the fitted line also shifted from approximately -0.439 to approximately 0.394.
#
# The scatter plot shows a clearer positive trend in the data after removing the outliers. The fitted line seems to better represent the relationship between the number of people invited and the number of people who attended.
#
# When the outliers were included, they were pulling the fitted line away from the general trend in the data. The outlier where 6 people were invited and only 4 attended was pulling the line down, while the outlier where 14 people were invited and 13 attended was pulling the line up. This resulted in a steeper slope and a negative intercept.
#
# Without the outliers, the data appears to follow a more consistent pattern, and the fitted line better represents this pattern. The slope is less steep, indicating a smaller increase in the number of attendees for each additional person invited, and the intercept is positive.
#
# This demonstrates how outliers can have a substantial impact on a linear regression model. In this case, removing the outliers made the model a better fit for the general trend in the data. However, it's important to remember that outliers can sometimes provide valuable information about variability in the data, and they shouldn't always be removed without careful consideration.
