# %% [markdown]
# # Lab: Regression Analysis

# %% [markdown]
# ### Before you start:
#
# * Read the README.md file
# * Comment as much as you can and use the resources (README.md file)
#
# Happy learning!

# %% [markdown]
# ## Challenge 1
# I work at a coding bootcamp, and I have developed a theory that the younger my students are, the more often they are late to class. In order to test my hypothesis, I have collected some data in the following table:
#
# | StudentID | Age | Tardies |
# |--------|-----|------------|
# | 1      | 17  | 10         |
# | 2      | 51  | 1          |
# | 3      | 27  | 5          |
# | 4      | 21  | 9         |
# | 5      | 36  |  4         |
# | 6      | 48  |  2         |
# | 7      | 19  |  9         |
# | 8      | 26  | 6          |
# | 9      | 54  |  0         |
# | 10     | 30  |  3         |

# %% [markdown]
# Use this command to create a dataframe with the data provided in the table.
# ~~~~
# student_data = pd.DataFrame({'X': [x_values], 'Y': [y_values]})
# ~~~~

# %%
# Libraries
from sklearn import linear_model
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os

# %%
# Your code here.

student_data = pd.DataFrame({'Age': [17,51,27,21,36,48,19,26,54,30], 'Tardies': [10,1,5,9,4,2,9,6,0,3]})
student_data
# Out:
#    Age  Tardies
# 0   17       10
# 1   51        1
# 2   27        5
# 3   21        9
# 4   36        4
# 5   48        2
# 6   19        9
# 7   26        6
# 8   54        0
# 9   30        3

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data.

# %%
# Your code here.
age = student_data[['Age']]
tardies = student_data[['Tardies']]
plt.scatter(age,tardies)
plt.ylabel('Tardies')
plt.xlabel('Age')
plt.title('Age over Tardies')
plt.show()

# %% [markdown]
# Do you see a trend? Can you make any hypotheses about the relationship between age and number of tardies?

# %%
# Your response here. 
# The data shows that the older you get the less late you are.
# It is a negative correlation.

# %% [markdown]
# Calculate the covariance and correlation of the variables in your plot. What is the difference between these two measures? Compare their values. What do they tell you in this case? Add your responses as comments after your code.

# %%
# Your response here.
#correlation:
correlation = np.corrcoef(student_data['Age'], student_data['Tardies'])[0, 1]
print ('The correlation is:', correlation)

#covariance:
covariance = np.cov(student_data['Age'], student_data['Tardies'])[0, 1]
print ('The covariance is:', covariance)


# The correlation is -0.93, so it is negative. Both two values are related but when one increases, the other decreases. It is a normalize value.
# The covariance depends on the values of the data, it only describes in which direction is the data going. This is a not normalize value, so the value is not that relevant.
# Out:
# The correlation is: -0.9391626886887122
# The covariance is: -45.56666666666666

# %% [markdown]
# Build a regression model for this data. What will be your outcome variable? What type of regression are you using? Add your responses as comments after your code.

# %%
# Your response here.
model = linear_model.LinearRegression()
result = model.fit(age,tardies)
b0 = result.intercept_
b1 = result.coef_

# The outcome variable will be the y axis (the tardies)
# This is a linear regression.
# So having the age, we will determine how late the person is.

# %% [markdown]
# Plot your regression model on your scatter plot.

# %%
# Your code here.

plt.plot(age, b0 + b1[0]*age, c='orange') #the orange line is the linear regression

#Blue dots for the scatter data that we have
plt.scatter(age,tardies)
plt.ylabel('Tardies')
plt.xlabel('Age')
plt.title('Age over Tardies')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Interpret the results of your model. What can conclusions can you draw from your model and how confident in these conclusions are you? Can we say that age is a good predictor of tardiness? Add your responses as comments after your code.

# %%
# Your response here.

# In the graph we can se that the model is pretty close with the data we have. 


from sklearn import metrics

squared_error = np.sqrt(metrics.mean_squared_error(tardies,result.predict(age)))

print('The squared error is:',squared_error)
score = result.score(age,tardies)
print ('The coefficient of determination is: ', score)

#The squared error is 1.15, that's how far away are from the real values, it is not a very big number.
#The coefficient of determination is 0.88, it is very close to 1, and it means that 88% of the data can be explained by our model.
#We can say the model is pretty close and it is a good predictor of tardiness.
# Out:
# The squared error is: 1.1540884648655088
# The coefficient of determination is:  0.8820265558250109

# %% [markdown]
# ## Challenge 2
# For the second part of this lab, we will use the vehicles.csv data set. You can find a copy of the dataset in the git hub folder. This dataset includes variables related to vehicle characteristics, including the model, make, and energy efficiency standards, as well as each car's CO2 emissions. As discussed in class the goal of this exercise is to predict vehicles' CO2 emissions based on several independent variables.

# %%
# Import any libraries you may need & the data
from sklearn import linear_model
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import metrics
import os

cars = pd.read_csv('vehicles.csv')
cars.head(5)
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# Let's use the following variables for our analysis: Year, Cylinders, Fuel Barrels/Year, Combined MPG, and Fuel Cost/Year. We will use 'CO2 Emission Grams/Mile' as our outcome variable.
#
# Calculate the correlations between each of these variables and the outcome. Which variable do you think will be the most important in determining CO2 emissions? Which provides the least amount of helpful information for determining CO2 emissions? Add your responses as comments after your code.

# %%
# Your response here.
car_analysis = cars[['Year', 'Cylinders', 'Fuel Barrels/Year', 'Combined MPG', 'Fuel Cost/Year', 'CO2 Emission Grams/Mile']]

columns = car_analysis.columns
list_results = []

for column in columns:
    if column != 'CO2 Emission Grams/Mile':
        correlation = np.corrcoef(car_analysis[column], car_analysis['CO2 Emission Grams/Mile'])[0,1]
        list_results.append((column, correlation))
        correlations = pd.DataFrame(list_results, columns=['C02 emissions vs.', 'Correlation Coefficient'])

#Data frame with the correlations sorted by descending
display(correlations.sort_values('Correlation Coefficient', ascending=False))

#Graph with the correlations
heatmap = sns.heatmap(car_analysis.corr(), annot=True,xticklabels=car_analysis.corr().columns,yticklabels=car_analysis.corr().columns)
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()



# We have the values sorted descending, and we can see the biggest values which are 0.98 from Fuel Barrels/Year, 0.93 from Fuel Cost/Year and then the 0.75 from Cylinders.
# And then we see the lowest: -0.92 from Combined MPG which is very relevant as well, even if it is negative.
# The year is the least relevant information, because is not very correlated.
# Out:
#    C02 emissions vs.  Correlation Coefficient
# 2  Fuel Barrels/Year                 0.986189
# 4     Fuel Cost/Year                 0.930865
# 1          Cylinders                 0.752393
# 0               Year                -0.222300
# 3       Combined MPG                -0.926229

# %% [markdown]
# Build a regression model for this data. What type of regression are you using? Add your responses as comments after your code.

# %%
# Your response here.

x = car_analysis[['Fuel Barrels/Year']]
y = car_analysis[['CO2 Emission Grams/Mile']]



model = linear_model.LinearRegression()
result = model.fit(x,y)

b0 = result.intercept_
b1 = result.coef_

plt.plot(x, b0 + b1[0]*x, c='orange')

plt.scatter(x,y)
plt.xlabel('Fuel Barrels/Year')
plt.ylabel('CO2 Emission Grams/Mile')
plt.title('CO2 Emission Grams/Mile over Fuel Barrels/Year')
plt.show

#I used a linear regression between the Fuel Barrels/Year and the emissions. They are extremely related, so we found a great model.
#We found that the Fuel Barrels/Year is also heavily correlated to the Fuel Cost/year and negativily correlated with Combined MPG, so those columns won't add much information.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Print your regression summary, and interpret the results. What are the most important varibles in your model and why? What can conclusions can you draw from your model and how confident in these conclusions are you? Add your responses as comments after your code.

# %%
# Your response here. 

error = round(np.sqrt(metrics.mean_squared_error(y, result.predict(x))),2)
print ('The squared error is:',error)

score = round(result.score(x,y),4)
print('The model predicts',score*100,'% of our data')

# The most important variables in the model are the ones that are way off the model of the linear regression. Like the ones with 0 fuel barrel/year and great emissions. We could analyse them in more detail later and see if there is an error in the data or if there is something interesting about that fuel.
# The squared mean error is 19.72, which is a really small number(and a good one), given that the data gets to 1200.
# And the model predicts 97.26% of our data.
# First we want to analyse the outliers so we can understand the data a little bit better.
# Out:
# The squared error is: 19.72
# The model predicts 97.26 % of our data

# %%
# Outliers
outliers = cars[cars['Fuel Barrels/Year']<1]
print(outliers.shape)
outliers.head(7)

#There are 60 outliers in total
# We found out that the outliers could have in common the Fuel Type: CNG
# Out:
# (60, 15)
#            Make                              Model  Year  Engine Displacement  \
# 5843  Chevrolet      Express Cargo (dedicated CNG)  2004                  6.0
# 5845  Chevrolet  Express Passenger (dedicated CNG)  2004                  6.0
# 7084  Chevrolet          Silverado 2500 HD 2WD CNG  2004                  6.0
# 7085  Chevrolet          Silverado 2500 HD 2WD CNG  2005                  6.0
# 7086  Chevrolet          Silverado 2500 HD 4WD CNG  2005                  6.0
# 9164      Dodge          Caravan/Grand Caravan 2WD  1993                  3.3
# 9171      Dodge          Caravan/Grand Caravan 2WD  1994                  3.3
#
#       Cylinders     Transmission                  Drivetrain  \
# 5843        8.0  Automatic 4-spd            Rear-Wheel Drive
# 5845        8.0  Automatic 4-spd            Rear-Wheel Drive
# 7084        8.0  Automatic 4-spd            Rear-Wheel Drive
# 7085        8.0  Automatic 4-spd            Rear-Wheel Drive
# ...

# %%
outliers['Fuel Type'].value_counts()

#As we thought, every outlier has CNG fuel type
# Out:
# CNG    60
# Name: Fuel Type, dtype: int64

# %%
cars_analysis_clean = cars[cars['Fuel Type']!='CNG'] #We clean the data from the first dataframe without those outliers.

#And prepare the model again with the cleaned values.
x_clean = cars_analysis_clean[['Fuel Barrels/Year']]
y_clean = cars_analysis_clean[['CO2 Emission Grams/Mile']]


model = linear_model.LinearRegression()
result = model.fit(x_clean,y_clean)

b0 = result.intercept_
b1 = result.coef_

plt.plot(x_clean, b0 + b1[0]*x_clean, c='orange')

plt.scatter(x_clean,y_clean)
plt.xlabel('Fuel Barrels/Year')
plt.ylabel('CO2 Emission Grams/Mile')
plt.title('CO2 Emission Grams/Mile over Fuel Barrels/Year')
plt.show

error = round(np.sqrt(metrics.mean_squared_error(y_clean, result.predict(x_clean))),2)
print ('The squared error is:',error)

score = round(result.score(x_clean,y_clean),4)
print('The model predicts',score*100,'% of our data')

#We had a squared mean error of 19.72 and now is 3.29
#And the model predicted 97.26% and now it predicts 99.92%
#Now we have an even better model and can be extremely confident about the results.
# Out:
# The squared error is: 3.29
# The model predicts 99.92 % of our data

# %%
cars[(cars['Fuel Barrels/Year']>10) & (cars['Fuel Barrels/Year']<14) & (cars['CO2 Emission Grams/Mile']>400)]

#We could omit this outliers to make an ever better model, but they are only 4 in a data set of thousands, so no very relevant, but we can keep an eye on them.
# Out:
#                      Make Model  Year  Engine Displacement  Cylinders  \
# 22470               Mazda     5  2013                  2.5        4.0
# 22471               Mazda     5  2013                  2.5        4.0
# 23242  McLaren Automotive    P1  2014                  3.8        8.0
# 23243  McLaren Automotive    P1  2015                  3.8        8.0
#
#           Transmission         Drivetrain  Vehicle Class  \
# 22470     Manual 6-spd  Front-Wheel Drive  Minivan - 2WD
# 22471   Automatic (S5)  Front-Wheel Drive  Minivan - 2WD
# 23242  Automatic 7-spd   Rear-Wheel Drive    Two Seaters
# 23243  Automatic 7-spd   Rear-Wheel Drive    Two Seaters
#
#                      Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  \
# 22470                  Regular          13.733750        21           28
# 22471                  Regular          13.733750        22           28
# 23242  Premium and Electricity          10.794366        16           20
# ...

# %% [markdown]
# ## Challenge 2: Error Analysis

# %% [markdown]
# I am suspicious about the last few parties I have thrown: it seems that the more people I invite the more people are unable to attend. To know if my hunch is supported by data, I have decided to do an analysis. I have collected my data in the table below, where X is the number of people I invited, and Y is the number of people who attended.
#
# |  X |  Y |
# |----|----|
# | 1  |  1 |
# | 3  |  2 |
# | 4  |  4 |
# | 6  |  4 |
# | 8  |  5 |
# | 9  |  7 |
# | 11 |  8 |
# | 14 |  13 |

# %% [markdown]
# We want to know if the relationship modeled by the two random variables is linear or not, and therefore if it is appropriate to model it with a linear regression.
# First, build a dataframe with the data.

# %%
# Your code here.

party = pd.DataFrame({'Invited':[1,3,4,6,8,9,11,14], 'Attended':[1,2,4,4,5,7,8,13]})

#We want to know how many people didn't come to have a better grasp about the data
party['Missing'] = party['Invited']-party['Attended']
party
# Out:
#    Invited  Attended  Missing
# 0        1         1        0
# 1        3         2        1
# 2        4         4        0
# 3        6         4        2
# 4        8         5        3
# 5        9         7        2
# 6       11         8        3
# 7       14        13        1

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data, and fit a regression line.

# %%
# Your code here.

x = party[['Invited']]
y = party[['Attended']]
#z = party[['Missing']]

#Our model
model = linear_model.LinearRegression()
result = model.fit(x,y)
b0 = result.intercept_
b1 = result.coef_

plt.scatter(x,y,c='blue',marker='X',label='Attended')
plt.plot(x, b0 + b1[0]*x, c='blue', label='Regression real attendance')

#The perfect attendance
plt.plot(x, x, c='lightsteelblue', label='Perfect attendance') 


#Labels
plt.xlabel('People invited')
plt.ylabel('People that came')
plt.title("Party attendance")
plt.legend()

plt.show()

# %% [markdown]
# What do you see? What does this plot tell you about the likely relationship between the variables? Print the results from your regression.

# %%
# Your response here. 

error = round(np.sqrt(metrics.mean_squared_error(y, result.predict(x))),2)
print ('The squared error is:',error)

score = round(result.score(x,y),4)
print('The model predicts',score*100,'% of our data')

# Now the model predicts 93.17% of our data, which is not bad. But we have a huge mean squared error given the data.
#It is very likely that the data is correlated
# Out:
# The squared error is: 0.93
# The model predicts 93.17 % of our data

# %% [markdown]
# Do you see any problematic points, or outliers, in your data? Remove these points and recalculate your regression. Print the new dispersion diagram with your new model and the results of your model.

# %%
# Your response here.

# The last point could be a little problematic, let's erase it and analyse again.

party_cleaned = party[party['Invited']!=14]
x_clean = party_cleaned[['Invited']]
y_clean = party_cleaned[['Attended']]


#Our cleaned model
model_clean = linear_model.LinearRegression()
result_clean = model_clean.fit(x_clean,y_clean)
b0_clean = result_clean.intercept_
b1_clean = result_clean.coef_

plt.scatter(x_clean,y_clean,c='blue',marker='X',label='Attended')
plt.plot(x_clean, b0_clean + b1_clean[0]*x_clean, c='blue', label='Regression real attendance')

#The perfect attendance
plt.plot(x_clean, x_clean, c='lightsteelblue', label='Perfect attendance') 


#Labels
plt.xlabel('People invited')
plt.ylabel('People that came')
plt.title("Party attendance")
plt.legend()

plt.show()

# %% [markdown]
# What changed? Based on the results of the two models and your graphs, what can you say about the form of the data with the problematic point and without it?

# %%
# Your response here.

#Now the model predicts that we will have a worse party. The slope of the line is getting away from the slope of the perfect attendance.
#But we got better results for our model, so it is more accurate.
#From an error of 0.93 to a 0.8 one.
#And now the model predicts 1% better, which is not much, but is better.

error = round(np.sqrt(metrics.mean_squared_error(y_clean, result.predict(x_clean))),2)
print ('The squared error is:',error)

score = round(result_clean.score(x_clean,y_clean),4)
print('The model predicts',score*100,'% of our data')
# Out:
# The squared error is: 0.8
# The model predicts 94.34 % of our data
