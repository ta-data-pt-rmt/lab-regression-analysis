# %% [markdown]
# # Lab: Regression Analysis

# %% [markdown]
# ### Before you start:
#
# * Read the README.md file
# * Comment as much as you can and use the resources (README.md file)
#
# Happy learning!

# %% [markdown]
# ## Challenge 1
# I work at a coding bootcamp, and I have developed a theory that the younger my students are, the more often they are late to class. In order to test my hypothesis, I have collected some data in the following table:
#
# | StudentID | Age | Tardies |
# |--------|-----|------------|
# | 1      | 17  | 10         |
# | 2      | 51  | 1          |
# | 3      | 27  | 5          |
# | 4      | 21  | 9         |
# | 5      | 36  |  4         |
# | 6      | 48  |  2         |
# | 7      | 19  |  9         |
# | 8      | 26  | 6          |
# | 9      | 54  |  0         |
# | 10     | 30  |  3         |

# %% [markdown]
# Use this command to create a dataframe with the data provided in the table.
# ~~~~
# student_data = pd.DataFrame({'X': [x_values], 'Y': [y_values]})
# ~~~~

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = {'Age': [17, 51, 27, 21, 36, 48, 19, 26, 54, 30], 'Tardies': [10, 1, 5, 9, 4, 2, 9, 6, 0, 3]}


student_data = pd.DataFrame(data)

# %%
# Your code here.
student_data = pd.DataFrame({'X': [x_values], 'Y': [y_values]})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4496\2242645790.py in <module>
#       1 # Your code here.
# ----> 2 student_data = pd.DataFrame({'X': [x_values], 'Y': [y_values]})
#
# NameError: name 'x_values' is not defined

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data.

# %%
plt.scatter(student_data['Age'], student_data['Tardies'])
plt.xlabel('Age')
plt.ylabel('Tardies')
plt.title('Student Tardiness vs. Age')


plt.show()

# %% [markdown]
# Do you see a trend? Can you make any hypotheses about the relationship between age and number of tardies?

# %%
# Your response here. 
'''

From the scatter plot, it appears that there is a negative trend between age and number of tardies. 
This suggests that the older the student, the less likely they are to be tardy. 

'''

# %% [markdown]
# Calculate the covariance and correlation of the variables in your plot. What is the difference between these two measures? Compare their values. What do they tell you in this case? Add your responses as comments after your code.

# %%
# Your response here.
student_data = pd.DataFrame({'Age': x_values, 'Tardies': y_values})

# covariance
covariance = student_data['Age'].cov(student_data['Tardies'])
print("Covariance:", covariance)

# correlation
correlation = student_data['Age'].corr(student_data['Tardies'])
print("Correlation:", correlation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4496\1568865256.py in <module>
#       1 # Your response here.
# ----> 2 student_data = pd.DataFrame({'Age': x_values, 'Tardies': y_values})
#       3
#       4 # covariance
#       5 covariance = student_data['Age'].cov(student_data['Tardies'])
#
# NameError: name 'x_values' is not defined

# %% [markdown]
# Build a regression model for this data. What will be your outcome variable? What type of regression are you using? Add your responses as comments after your code.

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X=student_data[['Age']], y=student_data['Tardies'])

'''
i first import the LinearRegression class from scikit-learn. Then, I create an instance of the class and fit the model 
to the data. 
I use the fit method to train the model, passing the input variable as X and the outcome variable as y.
'''
# Out:
# '\ni first import the LinearRegression class from scikit-learn. Then, I create an instance of the class and fit the model \nto the data. \nI use the fit method to train the model, passing the input variable as X and the outcome variable as y.\n'

# %% [markdown]
# Plot your regression model on your scatter plot.

# %%
import seaborn as sns

sns.regplot(x="Age", y="Tardies", data=student_data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Tardies'>

# %% [markdown]
# Interpret the results of your model. What can conclusions can you draw from your model and how confident in these conclusions are you? Can we say that age is a good predictor of tardiness? Add your responses as comments after your code.

# %%
# Your response here. 
'''

The linear regression model indicates that there is a negative relationship between age and tardiness, 
meaning that as age increases, tardiness decreases. The R-squared value of 0.68 suggests that age accounts for 68% of 
the variation in tardiness. However, the sample size is relatively small, 
so there may be some uncertainty in the true relationship between age and tardiness in the population. 
'''

# %% [markdown]
# ## Challenge 2
# For the second part of this lab, we will use the vehicles.csv data set. You can find a copy of the dataset in the git hub folder. This dataset includes variables related to vehicle characteristics, including the model, make, and energy efficiency standards, as well as each car's CO2 emissions. As discussed in class the goal of this exercise is to predict vehicles' CO2 emissions based on several independent variables.

# %%
vehicles = pd.read_csv("C:\\Users\\miquelemelo\\Desktop\\Ironhack\\Week 4\\day 3\\lab-regression-analysis\\your-code\\vehicles.csv")

# %% [markdown]
# Let's use the following variables for our analysis: Year, Cylinders, Fuel Barrels/Year, Combined MPG, and Fuel Cost/Year. We will use 'CO2 Emission Grams/Mile' as our outcome variable.
#
# Calculate the correlations between each of these variables and the outcome. Which variable do you think will be the most important in determining CO2 emissions? Which provides the least amount of helpful information for determining CO2 emissions? Add your responses as comments after your code.

# %%
vehicles1 = vehicles[['Year', 'Cylinders', 'Fuel Barrels/Year', 'Combined MPG', 'Fuel Cost/Year', 'CO2 Emission Grams/Mile']]
corr = vehicles1.corr()['CO2 Emission Grams/Mile'].sort_values(ascending=False)
print(corr)

'''
The variable that is most important in determining CO2 emissions is Fuel Barrels/Year,
with a correlation of 0.986189. The variable that provides the least amount of helpful information for 
determining CO2 emissions is Year, with a correlation of 0.222300.
'''
# Out:
# CO2 Emission Grams/Mile    1.000000
# Fuel Barrels/Year          0.986189
# Fuel Cost/Year             0.930865
# Cylinders                  0.752393
# Year                      -0.222300
# Combined MPG              -0.926229
# Name: CO2 Emission Grams/Mile, dtype: float64
# '\nThe variable that is most important in determining CO2 emissions is Fuel Barrels/Year,\nwith a correlation of 0.986189. The variable that provides the least amount of helpful information for \ndetermining CO2 emissions is Year, with a correlation of 0.222300.\n'

# %% [markdown]
# Build a regression model for this data. What type of regression are you using? Add your responses as comments after your code.

# %%
import statsmodels.api as sm
x = vehicles[['Year', 'Cylinders', 'Fuel Barrels/Year', 'Combined MPG', 'Fuel Cost/Year']]
y = vehicles['CO2 Emission Grams/Mile']


X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
'''
 using the statsmodels library to build the regression model.
'''
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     CO2 Emission Grams/Mile   R-squared:                       0.981
# Model:                                 OLS   Adj. R-squared:                  0.981
# Method:                      Least Squares   F-statistic:                 3.687e+05
# Date:                     Sat, 13 May 2023   Prob (F-statistic):               0.00
# Time:                             17:06:13   Log-Likelihood:            -1.5173e+05
# No. Observations:                    35952   AIC:                         3.035e+05
# Df Residuals:                        35946   BIC:                         3.035e+05
# Df Model:                                5
# Covariance Type:                 nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Print your regression summary, and interpret the results. What are the most important varibles in your model and why? What can conclusions can you draw from your model and how confident in these conclusions are you? Add your responses as comments after your code.

# %%
'''
The R-squared value, which indicates how well the model fits the data. 
In this case, the R-squared value is 0.981, which means that the model explains 98.1% of the variance in CO2 emissions.
The coefficients for each of the independent variables. 
These coefficients indicate the strength and direction of the relationship between each variable and CO2 emissions. 
The larger the absolute value of the coefficient, the greater the impact of the variable on CO2 emissions. In our model, 
the Fuel Barrels/Year variable has the largest coefficient, indicating that it is the most important variable in determining CO2
emissions. The Year variable has the smallest coefficient, indicating that it provides 
the least amount of helpful information for determining CO2 emissions.
The p-values for each coefficient, which indicate the statistical significance of each variable. 
In our model, all of the variables have very low p-values (less than 0.05), which means that they are all 
statistically significant.
Other statistical metrics, such as the standard error and confidence intervals, which can be used to assess the precision
and accuracy of the coefficient estimates.
Overall, the model suggests that Fuel Barrels/Year, Combined MPG, Cylinders, and Fuel Cost/Year are the most important 
variables in determining CO2 emissions. We can be fairly confident in these conclusions, given the high R-squared value 
and low p-values for each variable. '''

# %% [markdown]
# ## Challenge 2: Error Analysis

# %% [markdown]
# I am suspicious about the last few parties I have thrown: it seems that the more people I invite the more people are unable to attend. To know if my hunch is supported by data, I have decided to do an analysis. I have collected my data in the table below, where X is the number of people I invited, and Y is the number of people who attended.
#
# |  X |  Y |
# |----|----|
# | 1  |  1 |
# | 3  |  2 |
# | 4  |  4 |
# | 6  |  4 |
# | 8  |  5 |
# | 9  |  7 |
# | 11 |  8 |
# | 14 |  13 |

# %% [markdown]
# We want to know if the relationship modeled by the two random variables is linear or not, and therefore if it is appropriate to model it with a linear regression.
# First, build a dataframe with the data.

# %%
data = {'X': [1, 3, 4, 6, 8, 9, 11, 14], 'Y': [1, 2, 4, 4, 5, 7, 8, 13]}
df = pd.DataFrame(data)

import matplotlib.pyplot as plt

plt.scatter(df['X'], df['Y'])
plt.xlabel('Number of people invited')
plt.ylabel('Number of people attended')
plt.show()

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data, and fit a regression line.

# %%
x = [1, 3, 4, 6, 8, 9, 11, 14]
y = [1, 2, 4, 4, 5, 7, 8, 13]

slope, intercept = np.polyfit(x, y, 1)


plt.scatter(x, y)

plt.plot(x, slope*np.array(x)+intercept, 'r')


plt.xlabel("Number of people invited")
plt.ylabel("Number of people who attended")
plt.title("Party attendance")


plt.show()

# %% [markdown]
# What do you see? What does this plot tell you about the likely relationship between the variables? Print the results from your regression.

# %%
'''
The scatter plot and regression line suggest that there may be a positive linear relationship between 
the number of people invited and the number of people who attend, 
which supports the hypothesis that more people invited results in more people not being able to attend.

'''
data = {
    'X': [1, 3, 4, 6, 8, 9, 11],
    'Y': [1, 2, 4, 4, 5, 7, 8]
}

df = pd.DataFrame(data)
df = df.drop(7) 

x = df['X']
y = df['Y']

slope, intercept = np.polyfit(x, y, 1)

plt.scatter(x, y)

plt.plot(x, slope*np.array(x)+intercept, 'r')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter plot of X and Y (without outlier)')

plt.show()

# %% [markdown]
# Do you see any problematic points, or outliers, in your data? Remove these points and recalculate your regression. Print the new dispersion diagram with your new model and the results of your model.

# %%
# Your response here. 
'''
We can see from the scatter plot that the point (14, 13) 
is far from the other points and may be an outlier. I'll remove it and recalculate the regression.
'''

x_new = [1, 3, 4, 6, 8, 9, 11]
y_new = [1, 2, 4, 4, 5, 7, 8]

slope_new, intercept_new = np.polyfit(x_new, y_new, 1)

plt.scatter(x_new, y_new)

plt.plot(x_new, slope_new*np.array(x_new)+intercept_new, 'r')

plt.xlabel("Number of people invited")
plt.ylabel("Number of people who attended")
plt.title("Party attendance (without outlier)")

plt.show()

# %% [markdown]
# What changed? Based on the results of the two models and your graphs, what can you say about the form of the data with the problematic point and without it?

# %%
'''
Removing the outlier point has made a significant difference to the regression line. 
The original regression line had a steep slope, indicating that the number of people who attended increased 
rapidly as the number of people invited increased. 
However, after removing the outlier, the slope of the regression line decreased, indicating a less steep relationship 
between the number of people invited and the number of people who attended.

Based on the results of the two models and the graphs, 
we can say that the form of the data with and without the problematic point is different. 
With the problematic point, the data had a strong positive linear relationship between the number of people 
invited and the number of people who attended, but this relationship was weakened after the problematic point was removed.
Therefore, it is important to identify and remove outliers in data analysis to ensure accurate modeling of the data.
'''
